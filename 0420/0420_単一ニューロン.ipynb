# %% [markdown]
# ## 単一ニューロンがsinカーブを学習する例

# %% [markdown]
# ![single_neuron.png](data:image/png;base64,...)

# %% [markdown]
# # 正解データの描く曲線（sinカーブ）

# %%
import numpy as np
import matplotlib.pyplot as plt

# -- 入力と正解の用意 --
input_data = np.linspace(-np.pi/2, np.pi/2)  # 入力
correct_data = (np.sin(input_data) + 1)/2    # 正解 0-1の範囲に収める

# グラフに描画してみる
plt.plot(correct_data)
plt.show()

# 正解データの内容
print(correct_data)
# Out:
# [0.         0.0010273  0.00410499 0.00922042 0.01635257 0.02547213
#  0.03654162 0.04951557 0.06434065 0.08095595 0.09929319 0.11927702
#  0.14082532 0.16384955 0.1882551  0.21394167 0.24080372 0.26873085
#  0.29760833 0.32731747 0.35773621 0.38873953 0.42020005 0.45198849
#  0.48397421 0.51602579 0.54801151 0.57979995 0.61126047 0.64226379
#  0.67268253 0.70239167 0.73126915 0.75919628 0.78605833 0.8117449
#  0.83615045 0.85917468 0.88072298 0.90070681 0.91904405 0.93565935
#  0.95048443 0.96345838 0.97452787 0.98364743 0.99077958 0.99589501
#  0.9989727  1.        ]

# %% [markdown]
# # 入力データ
#
# この直線を正解データのような曲線に近づける学習を行う

# %%
input_data = np.linspace(-np.pi/2, np.pi/2)  # 入力
# グラフに描画してみる
plt.plot(input_data)
plt.show()

# 入力データの内容
print(input_data)
# Out:
# [-1.57079633 -1.50668219 -1.44256806 -1.37845392 -1.31433978 -1.25022565
#  -1.18611151 -1.12199738 -1.05788324 -0.9937691  -0.92965497 -0.86554083
#  -0.8014267  -0.73731256 -0.67319843 -0.60908429 -0.54497015 -0.48085602
#  -0.41674188 -0.35262775 -0.28851361 -0.22439948 -0.16028534 -0.0961712
#  -0.03205707  0.03205707  0.0961712   0.16028534  0.22439948  0.28851361
#   0.35262775  0.41674188  0.48085602  0.54497015  0.60908429  0.67319843
#   0.73731256  0.8014267   0.86554083  0.92965497  0.9937691   1.05788324
#   1.12199738  1.18611151  1.25022565  1.31433978  1.37845392  1.44256806
#   1.50668219  1.57079633]

# %% [markdown]
# # 単一ニューロンの学習の観察

# %%
import numpy as np
import matplotlib.pyplot as plt

# -- 入力と正解の用意 --
input_data = np.linspace(-np.pi/2, np.pi/2)  # 入力
correct_data = (np.sin(input_data) + 1)/2    # 正解
n_data = len(correct_data)                   # データ数

# -- 各設定値 --
eta = 0.1        # 学習係数
epoch = 100
# epoch = 30

# 各初期値
x = 0    # 入力
y = 0    # 出力
t = 0    # 正解

w = 0.2  # 重み
b = -0.2  # バイアス
grad_w = 0  # 重みの勾配
grad_b = 0  # バイアスの勾配


def forward():  # 順伝播
    global y  # 外部の変数を関数内で変更するには、globalの表記が必要
    
    u = x*w + b
    y = 1/(1+np.exp(-u))  # シグモイド関数
    
def backward():  # 逆伝播
    global grad_w
    global grad_b
    

    delta = (y - t)*(1-y)*y
    # 重みの勾配の計算
    grad_w = x * delta
    # バイアスの勾配の計算
    grad_b = delta
    
def update():  # 重みとバイアスの更新
    global w
    global b
    
    # 重みの更新
    # w = w - 学習係数×勾配
    # w = w - (eta * grad_w) と同じ
    w -= eta * grad_w
    # バイアスの更新
    b -= eta * grad_b
        

# -- 学習 --
# エポック回数分のループ
for i in range(epoch):
    
    # 結果の表示用
    plot_x = []
    plot_y = []
    
    # データ数分のループ
    for j in range(n_data):
        
        x = input_data[j]    # 入力
        t = correct_data[j]  # 正解
        
        # 順伝播
        forward()
        # 逆伝播
        backward()
        # 重みとバイアスの更新
        update()
        
        # 記録
        plot_x.append(x)
        plot_y.append(y)
            
    # グラフ表示
    plt.plot(input_data, correct_data, linestyle="dashed")  # 正解
    plt.scatter(plot_x, plot_y, marker="+")                 # 出力
    plt.show()
    
    # 重みとバイアス
    print("w:", w, "b:", b)
# Out:
# w: 0.49927978725832384 b: -0.13205185014597645
# w: 0.720544451047522 b: -0.08697207933507037
# w: 0.8894943753124486 b: -0.057432714289758824
# w: 1.0233520358668018 b: -0.03769479198254846
# w: 1.1327786810680662 b: -0.024184314530313902
# w: 1.2244929408231986 b: -0.014738813289455085
# w: 1.3028960560328622 b: -0.008024901546771362
# w: 1.370988347469074 b: -0.00319539925079586
# w: 1.4308899305690006 b: 0.00030456976182254524
# w: 1.4841463976230151 b: 0.002848654048787107
# w: 1.5319151228397911 b: 0.004694681541362501
# w: 1.5750829921037997 b: 0.006024369687135735
# w: 1.6143432975144762 b: 0.0069681588565552455
# w: 1.650247468813477 b: 0.007621172578424095
# w: 1.6832408046184297 b: 0.008053731914581568
# w: 1.7136877369399992 b: 0.008318437710083672
# w: 1.7418900717158043 b: 0.008455036849899912
# w: 1.7681004062437413 b: 0.008493825971079913
# w: 1.79253216559037 b: 0.008458070522502439
# w: 1.8153672242108176 b: 0.008365748871164064
# w: 1.8367617734633548 b: 0.008230826134270584
# w: 1.8568508951979321 b: 0.008064195455894702
# w: 1.8757521673938036 b: 0.007874380923640411
# w: 1.8935685363475585 b: 0.007668067526230293
# w: 1.9103906265152968 b: 0.007450504189984455
# w: 1.9262986144937226 b: 0.0072258127145380996
# w: 1.941363761773889 b: 0.006997226279532709
# w: 1.9556496778644155 b: 0.006767274780080099
# w: 1.969213368515042 b: 0.006537929698368805
# w: 1.9821061112829133 b: 0.0063107179546506974
# w: 1.9943741913388564 b: 0.0060868118152855545
# w: 2.006059523348724 b: 0.005867100204729929
# w: 2.0172001798785986 b: 0.005652245490679129
# w: 2.0278308426289 b: 0.005442728860511349
# w: 2.0379831895886227 b: 0.005238886693720497
# w: 2.047686228689317 b: 0.0050409397958911
# w: 2.0569665865612925 b: 0.004849016949578304
# w: 2.065848759427675 b: 0.004663173923364856
